# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiDhanush63/First/blob/main/SELABMID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=10
print("Addition of a and b is:",a+b)
# Out:
# Addition of a and b is: 15
